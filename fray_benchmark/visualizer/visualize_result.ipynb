# %%
# %load_ext autoreload
# %autoreload 2

from fray_benchmark.visualizer.bench_result import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Kick The Tire
#
# In this section, you will visualize the SCTBench results using different techniques, each running for one minute and one iteration. The results should resemble Figure 5(a) when the x-axis shows values less than one minute.

# %%
suite = BenchmarkSuite(["../../output/kickthetire/sctbench"])
ax = suite.generate_bug_over_time_fig("time")
fig = ax.get_figure()
# Out:
# /home/michael/Documents/software/fray-benchmark/fray_benchmark/visualizer/bench_result.py:443: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_grouped.groupby(['trial', 'Technique']).apply(interpolate_sum).reset_index(drop=True)

# %% [markdown]
# # RQ 1 Bug-finding effectiveness
#
# In this section, you will visualize the SCTBench, JaConTeBe results using different techniques, each running for 10 minute and one iteration. The results should resemble Figure 5(a) and 5(b).

# %%
# Figure 5(a)

sctsuite = BenchmarkSuite(["../../output/benchmark/sctbench"])
ax = sctsuite.generate_bug_over_time_fig("time")
fig = ax.get_figure()
# Out:
# /home/michael/Documents/software/fray-benchmark/fray_benchmark/visualizer/bench_result.py:443: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_grouped.groupby(['trial', 'Technique']).apply(interpolate_sum).reset_index(drop=True)

# %%
ax2 = sctsuite.generate_bug_over_iterations_fig("iterations")
fig = ax2.get_figure()
# Out:
# /home/michael/Documents/software/fray-benchmark/fray_benchmark/visualizer/bench_result.py:549: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_grouped.groupby(['trial', 'Technique']).apply(interpolate_sum).reset_index(drop=True)

# %%
ax2 = sctsuite.generate_bug_found_iterations_fig_not_found()
fig = ax2.get_figure()
# Out:
# Technique    Fray-Random     LLM  LLM-BLIND
# id
# sctbench-0           8.0     2.0        8.0
# sctbench-1         593.0  1605.0      735.0
# sctbench-10          1.0     1.0        1.0
# sctbench-11          2.0     1.0        4.0
# sctbench-12          1.0     1.0        1.0
# sctbench-13          1.0     1.0        1.0
# sctbench-14         38.0     2.0        2.0
# sctbench-15          8.0  3525.0       20.0
# sctbench-16         21.0    -1.0        2.0
# sctbench-17         27.0     2.0        2.0
# sctbench-18          6.0     1.0       10.0
# sctbench-19          3.0     1.0        1.0
# sctbench-2         158.0     2.0     1989.0
# sctbench-20          1.0     1.0        1.0
# sctbench-21          1.0     1.0        1.0
# sctbench-22          1.0     2.0        9.0
# sctbench-23         66.0    -1.0       17.0
# sctbench-24          2.0     1.0        7.0
# sctbench-25          2.0     2.0        9.0
# sctbench-26          1.0     1.0        2.0
# sctbench-27          1.0     3.0        2.0
# sctbench-3         176.0     8.0       35.0
# sctbench-4           2.0     8.0        6.0
# sctbench-5           1.0     1.0        1.0
# sctbench-6          12.0     2.0        6.0
# sctbench-7           2.0     1.0        1.0
# sctbench-8           1.0     1.0        2.0
# sctbench-9           2.0     1.0        1.0

# %%
ax2 = sctsuite.generate_bug_found_iterations_fig_not_found(False, False, True)
fig = ax2.get_figure()
# Out:
# Technique    Fray-Random     LLM  LLM-BLIND
# id
# sctbench-0           8.0     2.0        8.0
# sctbench-1         593.0  1605.0      735.0
# sctbench-14         38.0     2.0        2.0
# sctbench-15          8.0  3525.0       20.0
# sctbench-16         21.0    -1.0        2.0
# sctbench-17         27.0     2.0        2.0
# sctbench-2         158.0     2.0     1989.0
# sctbench-23         66.0    -1.0       17.0
# sctbench-25          2.0     2.0        9.0
# sctbench-3         176.0     8.0       35.0
# sctbench-4           2.0     8.0        6.0
# sctbench-6          12.0     2.0        6.0

# %%
# Figure 5(b)

jacontesuite = BenchmarkSuite(["../../output/benchmark/jacontebe"])
ax = jacontesuite.generate_bug_over_time_fig("time")
fig = ax.get_figure()
# Out:
# /home/michael/Documents/software/fray-benchmark/fray_benchmark/visualizer/bench_result.py:443: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_grouped.groupby(['trial', 'Technique']).apply(interpolate_sum).reset_index(drop=True)

# %%
ax2 = jacontesuite.generate_bug_found_iterations_fig_not_found()
fig = ax2.get_figure()
# Out:
# Technique     Fray-Random    LLM  LLM-BLIND
# id
# jacontebe-0           1.0    1.0        1.0
# jacontebe-1           1.0    1.0        1.0
# jacontebe-10         -1.0   -1.0       -1.0
# jacontebe-11          1.0    1.0        1.0
# jacontebe-12         -1.0   -1.0       -1.0
# jacontebe-13         -1.0   -1.0       -1.0
# jacontebe-14          1.0    1.0        1.0
# jacontebe-15          1.0    1.0        1.0
# jacontebe-16          1.0    1.0        1.0
# jacontebe-17          1.0    1.0        1.0
# jacontebe-18         -1.0   -1.0       -1.0
# jacontebe-19          3.0  964.0        1.0
# jacontebe-2          -1.0   -1.0       -1.0
# jacontebe-20          3.0    3.0        1.0
# jacontebe-21          1.0    1.0        1.0
# jacontebe-22         11.0   66.0       11.0
# jacontebe-3           1.0    1.0        1.0
# jacontebe-4           1.0    1.0        1.0
# jacontebe-5           1.0    1.0        1.0
# jacontebe-6           1.0    1.0        1.0
# jacontebe-7          -1.0   -1.0       -1.0
# jacontebe-8           1.0    1.0        1.0
# jacontebe-9           1.0    1.0        1.0

# %%
ax2 = jacontesuite.generate_bug_found_iterations_fig_not_found(True)
fig = ax2.get_figure()
# Out:
# Technique     Fray-Random    LLM  LLM-BLIND
# id
# jacontebe-10         -1.0   -1.0       -1.0
# jacontebe-12         -1.0   -1.0       -1.0
# jacontebe-13         -1.0   -1.0       -1.0
# jacontebe-18         -1.0   -1.0       -1.0
# jacontebe-19          3.0  964.0        1.0
# jacontebe-2          -1.0   -1.0       -1.0
# jacontebe-20          3.0    3.0        1.0
# jacontebe-22         11.0   66.0       11.0
# jacontebe-7          -1.0   -1.0       -1.0

# %%
ax2 = jacontesuite.generate_bug_over_iterations_fig("iterations")
fig = ax2.get_figure()
# Out:
# /home/michael/Documents/software/fray-benchmark/fray_benchmark/visualizer/bench_result.py:549: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_grouped = df_grouped.groupby(['trial', 'Technique']).apply(interpolate_sum).reset_index(drop=True)

# %% [markdown]
# # RQ 2: Run-time Performance
#
# In this section, you will visualize the run-time performance running the SCTBench, JaConTeBe using different techniques, each running for 10 minute and one iteration. The results should resemble Figure 6 and 7.

# %%
# Figure 6

suite = BenchmarkSuite([
    "../../output/benchmark/jacontebe",
    "../../output/benchmark/sctbench"
    ])
ax = suite.generate_search_space_table()
fig = ax.get_figure()

# %%
# Figure 7

ax = suite.generate_exec_speed_table()
fig = ax.get_figure()

# %% [markdown]
# # RQ 3: Applicability to Real-World Software
#
# This section evaluates Fray's bug-finding effectiveness on three real-world applications: Lucene, Kafka, and Guava. Running with the `pos` option displays the number of bugs detected in each application using Fray's POS algorithm.
#
# **Results Interpretation:**
# - **Test Run**: Number of tests executed successfully. When running partial evaluations (pos-only), this matches the test count shown in the **Real-world Bugs and Corresponding Run ID** section.
# - **Failure**: Number of tests that failed, indicating a bug was detected.
# - **Time**: Number of failures related to timing operations (thread.sleep, wait, etc.).
#
#
# Note that you may find more or fewer bugs depending on the CPU and memory resources you have. However, the results should be similar (within ±1) to those shown in the paper.

# %%
# Lucene

import pandas as pd

suite = BenchmarkSuite([
    "../../output/realworld/lucene",
    ])
suite.generate_bug_table()

# %%
# Guava

import pandas as pd

suite = BenchmarkSuite([
    "../../output/realworld/guava",
    ])
suite.generate_bug_table()

# %%
# Kafka

import pandas as pd

kafkasuite = BenchmarkSuite([
    "../../output/realworld/kafka",
    ])
kafkasuite.generate_bug_table()
# Out:
#           Technique  Test Run  Failure Time (FP)
# 0       Fray-Random       279       82    11 (0)
# 1  LLM-CONCURR-FUZZ       279       77    11 (0)

# %%
ax2 = kafkasuite.generate_bug_found_iterations_fig_not_found(True, True)

# %%
ax2 = suite.generate_bug_found_iterations_fig()

# %%
ax = suite.generate_exec_speed_table_prime()
# Out:
# Technique         id  original    ours   slowdown
# 0            kafka-0    1328.0  2077.0 -56.400602
# 1          kafka-100      19.0    17.0  10.526316
# 2          kafka-101      21.0    19.0   9.523810
# 3          kafka-102      21.0    20.0   4.761905
# 4          kafka-104      24.0    22.0   8.333333
# 5          kafka-105      18.0    17.0   5.555556
# 6          kafka-106      20.0    18.0  10.000000
# 7          kafka-108      20.0    19.0   5.000000
# 8          kafka-109      20.0    19.0   5.000000
# 9          kafka-112      19.0    16.0  15.789474
# 10         kafka-113      21.0    18.0  14.285714
# 11         kafka-114      24.0    23.0   4.166667
# 12         kafka-115      21.0    19.0   9.523810
# 13         kafka-116      19.0    16.0  15.789474
# 14         kafka-119      20.0    17.0  15.000000
# 15         kafka-120      21.0    19.0   9.523810
# 16         kafka-121      21.0    19.0   9.523810
# 17         kafka-122      24.0    21.0  12.500000
# 18         kafka-123      21.0    17.0  19.047619
# 19         kafka-124      24.0    20.0  16.666667
# 20         kafka-126      21.0    20.0   4.761905
# 21         kafka-127      20.0    20.0   0.000000
# 22         kafka-128      21.0    18.0  14.285714
# 23         kafka-130      24.0    21.0  12.500000
# 24         kafka-131      24.0    20.0  16.666667
# 25         kafka-133      19.0    18.0   5.263158
# 26         kafka-137      19.0    17.0  10.526316
# 27         kafka-138      21.0    20.0   4.761905
# 28         kafka-139      21.0    18.0  14.285714
# 29         kafka-140      23.0    19.0  17.391304
# 30         kafka-141      26.0    22.0  15.384615
# 31         kafka-142      23.0    20.0  13.043478
# 32         kafka-143      22.0    19.0  13.636364
# 33         kafka-144      19.0    18.0   5.263158
# 34         kafka-145      21.0    18.0  14.285714
# 35         kafka-146      22.0    17.0  22.727273
# 36         kafka-147      23.0    20.0  13.043478
# 37         kafka-148      24.0    19.0  20.833333
# 38         kafka-149      25.0    21.0  16.000000
# 39         kafka-150      20.0    18.0  10.000000
# 40         kafka-152      20.0    18.0  10.000000
# 41         kafka-153      25.0    21.0  16.000000
# 42         kafka-154      25.0    22.0  12.000000
# 43         kafka-155    2356.0  3169.0 -34.507640
# 44         kafka-156    1510.0  2066.0 -36.821192
# 45         kafka-157    1730.0  2284.0 -32.023121
# 46         kafka-158      10.0     8.0  20.000000
# 47         kafka-159      10.0     8.0  20.000000
# 48         kafka-160      10.0     9.0  10.000000
# 49         kafka-161      11.0     9.0  18.181818
# 50         kafka-162       9.0     8.0  11.111111
# 51         kafka-163       8.0     8.0   0.000000
# 52         kafka-164      10.0     8.0  20.000000
# 53         kafka-165      10.0     9.0  10.000000
# 54         kafka-166      10.0     9.0  10.000000
# 55         kafka-167       9.0     9.0   0.000000
# 56         kafka-168      10.0     8.0  20.000000
# 57         kafka-169      10.0     8.0  20.000000
# 58         kafka-170      10.0     8.0  20.000000
# 59         kafka-171      10.0     9.0  10.000000
# 60         kafka-172      10.0     9.0  10.000000
# 61         kafka-173      10.0     9.0  10.000000
# 62         kafka-174       9.0     8.0  11.111111
# 63         kafka-175      10.0     8.0  20.000000
# 64         kafka-177      10.0     8.0  20.000000
# 65         kafka-178      10.0     9.0  10.000000
# 66         kafka-179      11.0     9.0  18.181818
# 67         kafka-180       8.0     8.0   0.000000
# 68         kafka-181       9.0     8.0  11.111111
# 69         kafka-182       9.0     9.0   0.000000
# 70         kafka-183      10.0    10.0   0.000000
# 71         kafka-184      10.0     9.0  10.000000
# 72         kafka-185      10.0     8.0  20.000000
# 73         kafka-186      10.0     8.0  20.000000
# 74         kafka-187      10.0     8.0  20.000000
# 75         kafka-188      10.0     9.0  10.000000
# 76         kafka-189      11.0     9.0  18.181818
# 77         kafka-190      10.0     9.0  10.000000
# 78         kafka-193      10.0     8.0  20.000000
# 79         kafka-194      10.0     8.0  20.000000
# 80         kafka-195      11.0     9.0  18.181818
# 81         kafka-196      11.0     9.0  18.181818
# 82         kafka-197      10.0     9.0  10.000000
# 83         kafka-198      10.0     8.0  20.000000
# 84         kafka-199      10.0     9.0  10.000000
# 85         kafka-200      11.0     9.0  18.181818
# 86         kafka-201      11.0     9.0  18.181818
# 87         kafka-202      10.0     8.0  20.000000
# 88         kafka-203      10.0     9.0  10.000000
# 89         kafka-204       9.0     9.0   0.000000
# 90         kafka-205      11.0     8.0  27.272727
# 91         kafka-206      10.0     9.0  10.000000
# 92         kafka-207      10.0     8.0  20.000000
# 93         kafka-208      11.0     8.0  27.272727
# 94         kafka-209      11.0    10.0   9.090909
# 95         kafka-210      11.0     9.0  18.181818
# 96         kafka-211      10.0     9.0  10.000000
# 97         kafka-212      10.0     9.0  10.000000
# 98         kafka-213      10.0     8.0  20.000000
# 99         kafka-214      11.0     9.0  18.181818
# 100        kafka-215      11.0    11.0   0.000000
# 101        kafka-217       9.0     9.0   0.000000
# 102        kafka-218      10.0     9.0  10.000000
# 103        kafka-219      10.0     8.0  20.000000
# 104        kafka-220      11.0     9.0  18.181818
# 105        kafka-221      10.0    11.0 -10.000000
# 106        kafka-222      11.0     9.0  18.181818
# 107        kafka-223      29.0    25.0  13.793103
# 108        kafka-224     289.0   192.0  33.564014
# 109        kafka-249      20.0    17.0  15.000000
# 110        kafka-250      26.0    23.0  11.538462
# 111        kafka-252      25.0    22.0  12.000000
# 112        kafka-253      26.0    23.0  11.538462
# 113        kafka-254      29.0    31.0  -6.896552
# 114        kafka-255      33.0    31.0   6.060606
# 115        kafka-256      35.0    31.0  11.428571
# 116        kafka-257      37.0    32.0  13.513514
# 117        kafka-258      26.0    22.0  15.384615
# 118        kafka-259      26.0    23.0  11.538462
# 119        kafka-260      30.0    31.0  -3.333333
# 120        kafka-261      24.0    24.0   0.000000
# 121        kafka-262      35.0    30.0  14.285714
# 122        kafka-264     443.0   365.0  17.607223
# 123        kafka-265     488.0   430.0  11.885246
# 124        kafka-266     648.0   770.0 -18.827160
# 125        kafka-267     817.0   767.0   6.119951
# 126        kafka-268     982.0   736.0  25.050916
# 127        kafka-270     409.0   342.0  16.381418
# 128        kafka-271     522.0   441.0  15.517241
# 129        kafka-272     682.0   783.0 -14.809384
# 130        kafka-273     787.0   718.0   8.767471
# 131        kafka-277      21.0    16.0  23.809524
# 132        kafka-278     133.0   106.0  20.300752
# 133         kafka-29      21.0    21.0   0.000000
# 134         kafka-30      22.0    21.0   4.545455
# 135         kafka-31      21.0    20.0   4.761905
# 136         kafka-40      23.0    22.0   4.347826
# 137         kafka-41      21.0    20.0   4.761905
# 138         kafka-42      22.0    21.0   4.545455
# 139         kafka-70     101.0    97.0   3.960396
# 140         kafka-81      18.0    17.0   5.555556
# 141         kafka-85      21.0    20.0   4.761905
# 142         kafka-86      21.0    20.0   4.761905
# 143         kafka-88      19.0    17.0  10.526316
# 144         kafka-89      20.0    16.0  20.000000
# 145         kafka-90      19.0    18.0   5.263158
# 146         kafka-91      19.0    19.0   0.000000
# 147         kafka-93      20.0    19.0   5.000000
# 148         kafka-94      20.0    19.0   5.000000
# 149         kafka-95      20.0    17.0  15.000000
# 150         kafka-96      20.0    19.0   5.000000
# 151         kafka-97      20.0    19.0   5.000000
# 152         kafka-98      20.0    19.0   5.000000
# 153         kafka-99      21.0    18.0  14.285714
# Geometric mean of slowdown: 9.26%

# %% [markdown]
# # RQ 4:  Linearizability of Data Structures

# %%
import pandas as pd

suite = BenchmarkSuite([
    "../../output/realworld/lincheck",
    ])
suite.generate_bug_table()
